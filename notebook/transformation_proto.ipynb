# %%
# import pandas as pd
# from pymongo import MongoClient
# import os
# from dotenv import load_dotenv
# import certifi

# load_dotenv()
# mongo_db_url = os.getenv("MONGO_DB_URL")

# client = MongoClient(
#     mongo_db_url,
#     tls=True,
#     tlsCAFile=certifi.where()
# )

# db = client["ShivamAI"]
# collection = db["AQI_data"]

# raw_df = pd.DataFrame(list(collection.find()))

# %%
import pandas as pd

df=raw_df.copy()
df.head()
# Out:
#                         _id       City        Date  PM2_5  PM10     NO    NO2  \
# 0  6853f7380a97711fe0367bda  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22
# 1  6853f7380a97711fe0367bdb  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69
# 2  6853f7380a97711fe0367bdc  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30
# 3  6853f7380a97711fe0367bdd  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48
# 4  6853f7380a97711fe0367bde  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42
#
#      NOx  NH3     CO    SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  17.15  NaN   0.92  27.64  133.36     0.00     0.02    0.00  NaN       None
# 1  16.46  NaN   0.97  24.55   34.06     3.68     5.50    3.77  NaN       None
# 2  29.70  NaN  17.40  29.07   30.70     6.80    16.40    2.25  NaN       None
# 3  17.97  NaN   1.70  18.59   36.08     4.43    10.14    1.00  NaN       None
# 4  37.76  NaN  22.10  39.33   39.31     7.01    18.89    2.78  NaN       None

# %%
df.drop(columns='_id', inplace=True)

# %%
df.head(20)
# Out:
#          City        Date  PM2_5  PM10      NO    NO2     NOx  NH3      CO  \
# 0   Ahmedabad  2015-01-01    NaN   NaN    0.92  18.22   17.15  NaN    0.92
# 1   Ahmedabad  2015-01-02    NaN   NaN    0.97  15.69   16.46  NaN    0.97
# 2   Ahmedabad  2015-01-03    NaN   NaN   17.40  19.30   29.70  NaN   17.40
# 3   Ahmedabad  2015-01-04    NaN   NaN    1.70  18.48   17.97  NaN    1.70
# 4   Ahmedabad  2015-01-05    NaN   NaN   22.10  21.42   37.76  NaN   22.10
# 5   Ahmedabad  2015-01-06    NaN   NaN   45.41  38.48   81.50  NaN   45.41
# 6   Ahmedabad  2015-01-07    NaN   NaN  112.16  40.62  130.77  NaN  112.16
# 7   Ahmedabad  2015-01-08    NaN   NaN   80.87  36.74   96.75  NaN   80.87
# 8   Ahmedabad  2015-01-09    NaN   NaN   29.16  31.00   48.00  NaN   29.16
# 9   Ahmedabad  2015-01-10    NaN   NaN     NaN   7.04    0.00  NaN     NaN
# 10  Ahmedabad  2015-01-11    NaN   NaN  132.07  55.80   24.53  NaN  132.07
# ...

# %%
df.isna().sum()
# Out:
# City              0
# Date              0
# PM2_5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df.drop(columns=['AQI_Bucket'], inplace=True)

# %%
df.isna().sum()
# Out:
# City           0
# Date           0
# PM2_5       4598
# PM10       11140
# NO          3582
# NO2         3585
# NOx         4185
# NH3        10328
# CO          2059
# SO2         3854
# O3          4022
# Benzene     5623
# Toluene     8041
# Xylene     18109
# AQI         4681
# dtype: int64

# %%
city_counts = df['City'].value_counts()
print(city_counts)
# Out:
# City
# Ahmedabad             2009
# Delhi                 2009
# Mumbai                2009
# Bengaluru             2009
# Lucknow               2009
# Chennai               2009
# Hyderabad             2006
# Patna                 1858
# Gurugram              1679
# Visakhapatnam         1462
# Amritsar              1221
# Jorapokhar            1169
# Jaipur                1114
# Thiruvananthapuram    1112
# Amaravati              951
# Brajrajnagar           938
# Talcher                925
# Kolkata                814
# Guwahati               502
# Coimbatore             386
# Shillong               310
# Chandigarh             304
# Bhopal                 289
# Ernakulam              162
# Kochi                  162
# Aizawl                 113
# Name: count, dtype: int64

# %%
city_counts = df['City'].value_counts()
threshold = 800
minor_cities = city_counts[city_counts < threshold].index
df['City'] = df['City'].apply(lambda x: 'Other Cities' if x in minor_cities else x)

# %%
city_counts = df['City'].value_counts()
print(city_counts)
# Out:
# City
# Other Cities          2228
# Ahmedabad             2009
# Delhi                 2009
# Mumbai                2009
# Lucknow               2009
# Bengaluru             2009
# Chennai               2009
# Hyderabad             2006
# Patna                 1858
# Gurugram              1679
# Visakhapatnam         1462
# Amritsar              1221
# Jorapokhar            1169
# Jaipur                1114
# Thiruvananthapuram    1112
# Amaravati              951
# Brajrajnagar           938
# Talcher                925
# Kolkata                814
# Name: count, dtype: int64

# %%
import pandas as pd

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df.sort_values(by=['City', 'Date'], inplace=True)

def interpolate_city_group(group):
    group = group.set_index('Date')
    numeric_cols = group.select_dtypes(include='number')
    non_numeric_cols = group.select_dtypes(exclude='number')
    numeric_filled = numeric_cols.interpolate(method='time', limit_direction='both')
    filled_group = pd.concat([non_numeric_cols, numeric_filled], axis=1)
    
    return filled_group.reset_index()

df = df.groupby('City', group_keys=False).apply(interpolate_city_group).reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# Date           0
# City           0
# PM2_5          0
# PM10        2009
# NO             0
# NO2            0
# NOx         1169
# NH3         2009
# CO             0
# SO2            0
# O3             0
# Benzene     2281
# Toluene     3219
# Xylene     11285
# AQI            0
# dtype: int64

# %%
import pandas as pd

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
numeric_cols = df.select_dtypes(include='number').columns
df[numeric_cols] = df.groupby(['City', 'Year', 'Month'])[numeric_cols].transform(lambda x: x.fillna(x.median()))
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
df.isna().sum()
# Out:
# Date       0
# City       0
# PM2_5      0
# PM10       0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# Year       0
# Month      0
# dtype: int64

# %%
df.head()
# Out:
#         Date       City  PM2_5    PM10     NO    NO2    NOx    NH3     CO  \
# 0 2015-01-01  Ahmedabad  73.24  141.54   0.92  18.22  17.15  16.63   0.92
# 1 2015-01-02  Ahmedabad  73.24  141.54   0.97  15.69  16.46  16.63   0.97
# 2 2015-01-03  Ahmedabad  73.24  141.54  17.40  19.30  29.70  16.63  17.40
# 3 2015-01-04  Ahmedabad  73.24  141.54   1.70  18.48  17.97  16.63   1.70
# 4 2015-01-05  Ahmedabad  73.24  141.54  22.10  21.42  37.76  16.63  22.10
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI  Year  Month
# 0  27.64  133.36     0.00     0.02    0.00  209.0  2015      1
# 1  24.55   34.06     3.68     5.50    3.77  209.0  2015      1
# 2  29.07   30.70     6.80    16.40    2.25  209.0  2015      1
# 3  18.59   36.08     4.43    10.14    1.00  209.0  2015      1
# 4  39.33   39.31     7.01    18.89    2.78  209.0  2015      1

# %%
top_cities = df.groupby('City')['AQI'].mean().nlargest(6).index
filtered_df = df[df['City'].isin(top_cities)]

monthly = filtered_df.copy()
monthly['Month'] = monthly['Date'].dt.to_period('M')
monthly = monthly.groupby(['City', 'Month'])['AQI'].mean().reset_index()
monthly['Month'] = monthly['Month'].dt.to_timestamp()

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly, x='Month', y='AQI', hue='City')
plt.title("Monthly AQI Trend - Top 6 Cities by Average AQI")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['City'].value_counts()
# Out:
# City
# Other Cities          2228
# Ahmedabad             2009
# Lucknow               2009
# Bengaluru             2009
# Chennai               2009
# Delhi                 2009
# Mumbai                2009
# Hyderabad             2006
# Patna                 1858
# Gurugram              1679
# Visakhapatnam         1462
# Amritsar              1221
# Jorapokhar            1169
# Jaipur                1114
# Thiruvananthapuram    1112
# Amaravati              951
# Brajrajnagar           938
# Talcher                925
# Kolkata                814
# Name: count, dtype: int64

# %%
import numpy as np

target_count = 1800

# Function to extend a city's data
def upsample_city(df_city, target_count):
    if len(df_city) >= target_count:
        return df_city  # No need to upsample

    df_city = df_city.sort_values('Date')
    n_missing = target_count - len(df_city)

    # Take last N days for pattern (you can adjust 30 to 60 etc.)
    window = 30
    pattern = df_city.tail(window).copy()

    # Generate future dates
    last_date = df_city['Date'].max()
    future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=n_missing)

    # Repeat pattern
    repeat_pattern = pd.concat([pattern]*int(np.ceil(n_missing / window)), ignore_index=True).iloc[:n_missing]
    repeat_pattern = repeat_pattern.reset_index(drop=True)
    repeat_pattern['Date'] = future_dates
    repeat_pattern['City'] = df_city['City'].iloc[0]

    # Combine
    return pd.concat([df_city, repeat_pattern], ignore_index=True)

# Apply to selected small cities
small_cities = ['Visakhapatnam', 'Amritsar', 'Jorapokhar', 'Jaipur', 'Thiruvananthapuram',
                'Amaravati', 'Brajrajnagar', 'Talcher', 'Kolkata', 'Gurugram']

df_upsampled = (
    df.groupby('City', group_keys=False)
      .apply(lambda g: upsample_city(g, target_count) if g['City'].iloc[0] in small_cities else g)
      .reset_index(drop=True)
)
